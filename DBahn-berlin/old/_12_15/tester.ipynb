# %%
DSN = "postgresql://USER:PASS@localhost:5432/DBNAME"
DDL = "ddl.sql"
STATIONS = "station_data.json"
TIMETABLE_DIR = "timetable"
CHANGES_DIR = "timetable_changes"
SIM = 0.45

# %%
# %run test.py --dsn $DSN --ddl $DDL --station-json $STATIONS --timetable-dir $TIMETABLE_DIR --changes-dir $CHANGES_DIR --sim-threshold $SIM
# Out:
# <class 'str'> 'postgresql://USER:PASS@localhost:5432/DBNAME'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File C:\CodingProjects\DIA\DBahn-berlin\test.py:633
#     629     print("Done.")
#     632 if __name__ == "__main__":
# --> 633     main()
#
# File C:\CodingProjects\DIA\DBahn-berlin\test.py:613, in main()
#     610 args = ap.parse_args()
#     612 print(type(args.dsn), repr(args.dsn))
# --> 613 conn = psycopg2.connect(args.dsn, options="-c client_encoding=UTF8")
#     614 conn.autocommit = False
#     616 # 1) DDL
#
# File c:\Users\User\anaconda3\envs\seminar\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# ...
